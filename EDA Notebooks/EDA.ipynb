# %% [markdown]
# # Regression project: Real Estate Assessment Evaluation
# Home valuation is key in real estate industry, and also the basis for mortgages in credit sector. Here we have to predict the estimated value of a property.
#
# Data (RegressionSupervisedTrain.csv) consist of a list of features plus the resulting "parcelvalue", described in "Casedatadictionary.xlsx" file. Each row corresponds to a particular home valuation, and "transactiondate" is the date when the property was effectively sold. Properties are defined by "lotid", but be aware that one property can be sold more than once (it's not the usual case). Also notice that some features are sometimes missing, your model has to deal with it.
#
# Note that you should not use "totaltaxvalue", "buildvalue" or "landvalue", because they are closely correlated with the final value to predict. There is a further member of the training set predictors which is not available in the test set and therefore needs removing. Using this data build a predictive model for "parcelvalue"
#
# In your analysis, use the RMSE (Root Mean Squared Error) criterion for choosing any hyperparameters. Try a first quick implementation, then try to optimize hyperparameters.
#
# For this analysis there is an extra test dataset. Once your code is submitted we will run a competition to see how you score in the test data. Hence, have prepared also the necessary script to compute the MSE estimate on the test data once released.
# Bonus: Try an approach to fill NA without removing features or observations, and check improvements.
#
# You can follow those steps in your first implementation:
# * Explore and understand the dataset. Report missing data
# * Remove columns 'totaltaxvalue', 'buildvalue' or 'landvalue' from the training and testing set and also 'mypointer' from the training set
# * As a simplified initial version, get rid of missing data by:
#     - Removing features that have more than 40% of missing data in the training set (remember anything you remove from the training set must be removed form the testing set!) (HINT: data.dropna(axis=1, thresh=round(mypercentagevalid*len(data.index)) - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)
#     - After that, removing observations that have missing data
# * Create dummy variables for relevant categorical features (EXTENDED PROJECT ONLY)
# * Build your model and test it on the same input data
# * Assess expected accuracy using cross-validation
# * Report which variable impacts more on results
# * Prepare the code to run on a new input file and be able to report accuracy, following same preparation steps (missing data, dummies, etc)
#
# Note that you should not use *totaltaxvalue*, *buildvalue *or *landvalue*, because they are closely correlated with the final value to predict.
#
# You may want to iterate to refine some of these steps once you get performance results in step 5.

# %% [markdown]
# # 1. Load in libraries and data

# %%
# !source venv/bin/activate
# Basic libraries
import pandas as pd
import numpy as np
from scipy.stats import skew
import geopandas as gpd
from shapely.geometry import Point

# Sklearn
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures, StandardScaler, FunctionTransformer,MinMaxScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import GridSearchCV, cross_val_predict, KFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import root_mean_squared_error
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from category_encoders import TargetEncoder

# Visualisation
import plotly_express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import math
from scipy.stats import linregress, zscore
# Basic functions

## Log transformation
def log_transform(x):
    #print(x)
    return np.log(x + 1)


from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# Read in data

# %%
train = pd.read_csv("../data/Regression_Supervised_Train.csv")
test = pd.read_csv("../data/Regression_Supervised_Test.csv")

# Drop these features according to the instructions. mypointer is only present in the training set, so is dropped
drop_train = ['buildvalue', 'landvalue', 'mypointer', 'logerror', 'totaltaxvalue', 'lotid']
drop_test = ['buildvalue', 'landvalue', 'logerror', 'totaltaxvalue']

train = train.drop(drop_train, axis = 1)
test = test.drop(drop_test, axis = 1)
print(f"Training:{train.shape}, \n Test:{test.shape}")
# Out:
# Training:(24755, 42),
#  Test:(2746, 42)

# %% [markdown]
# ## Missing values

# %%
percent_missing_train = train.isnull().sum() * 100 / len(train)
percent_missing_test = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({
                                 'data_type':train.dtypes,
                                 'percent_missing_train': percent_missing_train,
                                      'percent_missing_test':percent_missing_test})
missing_value_df.sort_values(by = 'percent_missing_train', ascending = False)
# Out:
#                    data_type  percent_missing_train  percent_missing_test
# perimeterarea        float64             100.000000            100.000000
# classbuild           float64              99.927287            100.000000
# storytype            float64              99.773783            100.000000
# basement             float64              99.773783            100.000000
# totalarea            float64              99.749546            100.000000
# fireplace             object              99.240557             99.854334
# style                float64              99.058776             99.963583
# material             float64              98.994143             99.927167
# decktype             float64              97.123813            100.000000
# taxdelinquencyyear   float64              96.420925             94.573926
# taxdelinquencyflag    object              96.420925             94.573926
# poolarea             float64              95.128257            100.000000
# tubflag               object              94.970713             98.579752
# transactiondate       object              92.878206             93.627094
# num34bath            float64              79.725308             99.745084
# finishedarea1st      float64              75.184811            100.000000
# finishedareaEntry    float64              75.184811            100.000000
# numstories           float64              61.082610             99.380918
# garagearea           float64              59.628358             99.344501
# garagenum            float64              59.628358             99.344501
# poolnum              float64              48.612402             41.077932
# aircond              float64              41.571400             19.155135
# qualitybuild         float64              40.803878              1.383831
# unitnum              float64              40.371642              0.691916
# neighborhoodcode     float64              39.297112              0.000000
# heatingtype          float64              36.218946              0.000000
# lotarea              float64               2.864068              0.000000
# finishedarea         float64               0.254494              0.000000
# numfullbath          float64               0.145425              0.000000
# citycode             float64               0.125227              0.000000
# year                 float64               0.048475              0.000000
# regioncode           float64               0.008079              0.000000
# countycode             int64               0.000000              0.000000
# countycode2            int64               0.000000              0.000000
# parcelvalue          float64               0.000000                   NaN
# numfireplace           int64               0.000000              0.000000
# numbath              float64               0.000000              0.000000
# numbedroom             int64               0.000000              0.000000
# longitude              int64               0.000000              0.000000
# latitude               int64               0.000000              0.000000
# roomnum                int64               0.000000              0.000000
# taxyear                int64               0.000000              0.000000
# lotid                    NaN                    NaN              0.000000

# %% [markdown]
# ## Handling Missing Data
# The data set has many features with missing values. I use the following rules to deal with them:
# #### 1. For features with $>$ 40\% missing observations and no intuitive way of inferring, I drop them.
# - perimeterarea - drop
# - classbuild - drop
# - storytype - drop
# - totalarea - drop
# - style - drop
# - material - drop
# - finishedarea1st - drop feature
# - transaction date - drop; No information on this feature
#
# #### 2. For the following features, NAN most likely means that the feature is not present. For eg, missing observation of poolnum is most likely that there are no pools in the house; such observations have the corresponding poolarea as missing too. Hence, I impute 0/False/N for such features.
# - basement - missing is 0
# - unitnum - missing is 0
# - dectype - missing is 0
# - taxdelinquencyyear - make it to zero
# - num34bath - missing is 0
# - garagearea - make it zero
# - pool area - make it zero
# - gargenum - missing is 0
# - poolnum - missing is 0
# - tubflag - missing is False
# - fireplace - missing is False - Can be dropped, all info captured by numfireplace
# - taxdelinquencyflag - N if no delinquency
#
# #### 3. The following features are imputed.
# - aircond - missing is not 0 as the dictionary has the option for None. Impute mode
# - quality - impute
# - unitnum - impute
# - heatingtype - missing is not 0 as the dictionary has the option for None. Impute mode
# - lotarea - impute
# - finishedarea - impute
# - numfullbath - impute
# - year - convert to age
# - totaltaxvalue - impute
# - finishedareaEntry - impute
#
# #### 4. Will be dealt with later
# - regioncode
# - neighbourhoodcode
# - citycode

# %% [markdown]
# When missing indicates absence of feature - code it as 0 for the identified features.
# - For the other features, I'll impute them in the pipeline.
# - Numbath is a linear combo of num34bath and numfullbaths - can be dropped
# - Fireplace - is redundant with numfireplaces

# %%
drop = ['perimeterarea', 'classbuild', 'storytype', 'totalarea', 'style',
        'material', 'transactiondate', 'finishedarea1st', 'fireplace', 'numbath']
train = train.drop(drop, axis = 1)
test = test.drop(drop, axis = 1)
print(f"Training:{train.shape}, \n Test:{test.shape}")


impute_zero = ['basement',  'decktype', 'num34bath', 'garagearea', 'poolarea', 'taxdelinquencyyear', 'garagenum', 'poolnum']
impute_false = ['tubflag'] # 
impute_no = ['taxdelinquencyflag']
present_year = 2020

def preprocess(df, present_year=2020):
    df = df.copy()  
    
    # Impute numeric with 0 
    df = df.assign(**{col: df[col].fillna(0) for col in impute_zero if col in df})
    
    # Impute boolean with False
    df = df.assign(**{col: df[col].fillna(False) for col in impute_false if col in df})
    
    # Impute string categorical with "N"
    df = df.assign(**{col: df[col].fillna("N") for col in impute_no if col in df})
    
    # Convert year columns to age of house
    for col in ['year', 'taxyear']:
        if col in df:
            df[col] = present_year - df[col]
    
    return df

# Apply to both
train = preprocess(train)
test = preprocess(test)
# Out:
# Training:(24755, 32),
#  Test:(2746, 32)
# /var/folders/z1/06t5y7z11fz24b5p636_mqnr0000gn/T/ipykernel_5350/1479162939.py:20: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.assign(**{col: df[col].fillna(False) for col in impute_false if col in df})
# /var/folders/z1/06t5y7z11fz24b5p636_mqnr0000gn/T/ipykernel_5350/1479162939.py:20: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.assign(**{col: df[col].fillna(False) for col in impute_false if col in df})

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ## Skew
# Skew of the target variable is positive i.e. long right tails.
# Since we are using a linear model, it works best on symmetrically distributed data.
# - Reduces influence of outliers
# - Linearise non-linear relationships
# - Deals with heteroskedasticity

# %%
# Calculate skew
print(f"Skew of target feature {skew(train.parcelvalue)}") # 10.924666213432062

# The target has a positive skew. Log transform the variable to get a more symmetrical distribution
train['log_parcelvalue'] = np.log(train['parcelvalue'])

# Calculate skew and visualize
print(f"Skew of target feature after log transformation {skew(train.log_parcelvalue)}")

# Histograms
fig, axes = plt.subplots(1, 2, figsize=(9, 3), sharey=True)
fig.suptitle('Skew of Target Variable')
## Original
sns.histplot(ax=axes[0], x = train.parcelvalue)
axes[0].set_title('Parcelvalue')
## Log transformed
sns.histplot(ax=axes[1], x = train.log_parcelvalue)
axes[1].set_title('Log(Parcelvalue)')
# Out:
# Skew of target feature 10.924666213432062
# Skew of target feature after log transformation 0.12866162749355226
# Text(0.5, 1.0, 'Log(Parcelvalue)')

# %% [markdown]
# Get required columns
# See data dictionary for the feature definitions.

# %%
categorical = ['aircond', 'qualitybuild', 'decktype', 'tubflag', 'heatingtype',
               'taxdelinquencyflag', 'countycode', 'countycode2','regioncode',
                'neighborhoodcode', 'citycode', 'unitnum']

numerical =   ['basement', 'numbedroom', 'finishedarea',
               'finishedareaEntry', 'numfireplace', 'numfullbath', 'garagenum', 
               'garagearea', 'lotarea', 'poolnum', 'poolarea', 'roomnum', 
               'num34bath', 'year', 'numstories', 'taxyear',
               'taxdelinquencyyear']

# %% [markdown]
# Skew of numerical features. 12 out of 19 features have a skew greater than 1. Hence, it is best to log transform all numerical features

# %%
# Calculate skew
skew_df = pd.DataFrame(train[numerical].skew(skipna = True)).abs()
print(f"% Features with skew greater than 1 is {skew_df[skew_df[0] > 1]}")
# Out:
# % Features with skew greater than 1 is                             0
# basement            34.786710
# finishedarea         3.534346
# finishedareaEntry    3.140212
# numfireplace         2.423594
# numfullbath          1.726680
# garagenum            1.187571
# garagearea           1.585248
# lotarea             10.063577
# poolarea             4.837032
# num34bath            1.655079
# taxdelinquencyyear   5.081086

# %% [markdown]
# ## Plots
# Now I look at the joint distribution of the features and target variable. Since the task is to use linear regression, I also fit the OLS line of best fit with $CI = 95\%$
#
# Looking at the regression plots, I identify the following candidates for polynomial transformation: ['finishedarea', 'finishedareaEntry' ]
#
# Most features do exhibit a linear relationship.
# Notes:
# 1. It doesn't make sense to treat longitude and latitude as affecting the target in a linear manner. I will use a clustering algorithm and use the cluster labels instead of lat/long in the model.
# 2. roomnum and lotarea have a lot of zeroes which doesn't make sense - these are likely to have been miscoded or where the interpretation is wrong - Deal with them in feature engineering.

# %% [markdown]
# ## Histograms - Numerical features

# %%
n_cols = 4
n_feats = len(numerical)
n_rows = math.ceil(n_feats / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))

axes = axes.flatten()  

for i, feat in enumerate(numerical):
    sns.histplot(train[feat], ax=axes[i], kde=True)
    axes[i].set_title(feat)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Histograms - Categorical features
# - Region and county codes have very high cardinality - leave them out from the simple model for now.

# %%
n_cols = 4
n_feats = len(categorical)
n_rows = math.ceil(n_feats / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))

axes = axes.flatten()  

for i, feat in enumerate(categorical):
    sns.histplot(train[feat], ax=axes[i], kde=True)
    axes[i].set_title(feat)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Scatterplot

# %%
train_dropped_nas = train.dropna(subset= numerical,how = 'any',axis = 0)

n_cols = 4
n_feats = len(numerical)
n_rows = math.ceil(n_feats / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))

axes = axes.flatten()  

for i, feat in enumerate(numerical):
    sns.regplot(ax = axes[i], x = train[feat], y= train['log_parcelvalue'], ci = 95, line_kws = {'color':'red'})
    slope, intercept, r_value, p_value, std_err = linregress(zscore(train[feat]), train['log_parcelvalue'])

    axes[i].set_title(f"{feat}, slope={slope:.3f},  R²={r_value**2:.3f}")
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

# Hide extra 
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

fig.tight_layout()
plt.show()

# %% [markdown]
# # 3.  Fitting a simple model

# %% [markdown]
# Run a baseline model with no feature engineering and leaving out high cardinality categorical features.

# %%
categorical_simple = ['aircond', 'qualitybuild', 'decktype', 'tubflag', 'heatingtype',
               'taxdelinquencyflag', 'unitnum']

numerical_simple =   ['basement', 'numbedroom', 'finishedarea',
               'finishedareaEntry', 'numfireplace', 'numfullbath', 'garagenum', 
               'garagearea', 'lotarea', 'poolnum', 'poolarea', 'roomnum', 
               'num34bath', 'year', 'numstories', 'taxyear',
               'taxdelinquencyyear']

# %%
X_simple = train.drop(['parcelvalue', 'log_parcelvalue', 'longitude', 'latitude',
                        'countycode', 'countycode2', 'regioncode',
                          'neighborhoodcode', 'citycode'], axis = 1)
y = train['log_parcelvalue']
print(f"Features:{X_simple.shape}, \n Target:{y.shape}")
# Out:
# Features:(24755, 24),
#  Target:(24755,)

# %% [markdown]
# Initiate the regression pipeline, assign the appropriate features to the appropriate preporcessors

# %%
log_tranformer = FunctionTransformer(log_transform)

poly_features = ['finishedarea', 'finishedareaEntry' ]

numeric_transformer = Pipeline(
             steps = [
                      ("imputer", SimpleImputer(strategy = 'median')),
                      ("log", log_tranformer),
                #       ("poly", PolynomialFeatures(degree = 3)),
                      ("scaler", StandardScaler())
                      ])

poly_transformer = Pipeline(
             steps = [
                      ("imputer", SimpleImputer(strategy = 'median')),
                      ("log", log_tranformer),
                      ("poly", PolynomialFeatures(degree = 3)),
                      ("scaler", StandardScaler())
                      ])

categorical_transformer = Pipeline(
             steps = [ ("imputer", SimpleImputer(strategy = "most_frequent")),
                        ( "ohe", OneHotEncoder(
                                                handle_unknown='ignore',
                                                sparse_output=False))])

# preprocessor pipeline combining both:
preprocessor = ColumnTransformer(transformers=[
        ("num", numeric_transformer, numerical_simple),
        ("poly", poly_transformer, poly_features),
        ("cat", categorical_transformer, categorical_simple),
        ])

# Define the pipeline for preprocessing and the classifier.
regression_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('regression', LinearRegression())])

# Check structure of pipeline:
regression_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('log',
#                                                                    FunctionTransformer(func=<function log_transform at 0x10d888af0>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['basement', 'numbedroom',
#                                                    'finishedarea',
#                                                    'finishedareaEntry',
#                                                    'numfireplace',
#                                                    'numfullbath', 'garagenum',
#                                                    'garagearea', 'lo...
#                                                                    PolynomialFeatures(degree=3)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['finishedarea',
#                                                    'finishedareaEntry']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['aircond', 'qualitybuild',
#                                                    'decktype', 'tubflag',
#                                                    'heatingtype',
#                                                    'taxdelinquencyflag',
#                                                    'unitnum'])])),
#                 ('regression', LinearRegression())])

# %% [markdown]
# ## Model performance
# - I compare four models - Linear regression, and 3 regularised models.
# - All models perform 'similarly' on both train and test sets.
# - No signficant gain from regularisation - linear regression is not overfitting too much and has 'good' amount of bias.

# %% [markdown]
# ### Simple Linear Regression
# ### Kaggle Private Score - 659,364
# ### In-sample RMSE: 0.569816067625646

# %%
# Get cross validated predictions
y_hat_in = cross_val_predict(regression_pipeline, X_simple, y, cv = 5)

# Check in sample RMSE
print(f"RMSE = {root_mean_squared_error(y,y_hat_in)}")

# Fit model
regression_pipeline.fit(X_simple, y)

# Predict on test set and undo the logarithmic transformation of target feature
y_hat_test = np.exp(regression_pipeline.predict(test[X_simple.columns]))

# Create datafram of predictions
test_predictions_submit = pd.DataFrame({"lotid": test["lotid"], "parcelvalue": y_hat_test})

# Dataframe to csv
test_predictions_submit.to_csv("test_predictions_linreg.csv", index = False)
# Out:
# RMSE = 0.569816067625646

# %% [markdown]
# ## Regularisation
# ### L1: Lasso
# ### Kaggle Private Score: 662,537
# ### In-sample RMSE: 0.5697383343865633, alpha = 0.001

# %%
# Define the pipeline for preprocessing and the classifier.
lasso_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('Lasso', Lasso())])

# Check structure of pipeline:
lasso_pipeline

param_grid = {

                'Lasso__alpha' : [0.001, 0.005, 0.01, 0.025, 0.05, 0.1, 0.5, 1, 5, 10, 25, 50, 100]
                     } 
# Initiate grid search object
grid_search_lasso = GridSearchCV(lasso_pipeline,
                           param_grid,
                           cv = 5,
                           scoring = "neg_root_mean_squared_error",
                           verbose = 10)
# Fit the grid search
grid_search_lasso.fit(X_simple, y)

# Get best parameters
print(grid_search_lasso.best_params_)

# Get in sampple predictions and RMSE
y_hat_in_lasso = grid_search_lasso.predict(X_simple)

# Check in sample RMSE
print(f"RMSE = {root_mean_squared_error(y, y_hat_in_lasso)}") # RMSE = 0.5479937081116162 (log values)

y_hat_test_lasso = np.exp(grid_search_lasso.predict(test[X_simple.columns]))
test_predictions_submit = pd.DataFrame({"lotid": test["lotid"], "parcelvalue": y_hat_test_lasso})
test_predictions_submit.to_csv("test_predictions_lasso.csv", index = False)
# Out:
# Fitting 5 folds for each of 13 candidates, totalling 65 fits
# [CV 1/5; 1/13] START Lasso__alpha=0.001.........................................
# [CV 1/5; 1/13] END .........Lasso__alpha=0.001;, score=-0.570 total time=   0.9s
# [CV 2/5; 1/13] START Lasso__alpha=0.001.........................................
# [CV 2/5; 1/13] END .........Lasso__alpha=0.001;, score=-0.564 total time=   0.9s
# [CV 3/5; 1/13] START Lasso__alpha=0.001.........................................
# [CV 3/5; 1/13] END .........Lasso__alpha=0.001;, score=-0.573 total time=   0.8s
# [CV 4/5; 1/13] START Lasso__alpha=0.001.........................................
# [CV 4/5; 1/13] END .........Lasso__alpha=0.001;, score=-0.570 total time=   0.9s
# [CV 5/5; 1/13] START Lasso__alpha=0.001.........................................
# [CV 5/5; 1/13] END .........Lasso__alpha=0.001;, score=-0.575 total time=   0.9s
# [CV 1/5; 2/13] START Lasso__alpha=0.005.........................................
# [CV 1/5; 2/13] END .........Lasso__alpha=0.005;, score=-0.577 total time=   0.6s
# [CV 2/5; 2/13] START Lasso__alpha=0.005.........................................
# [CV 2/5; 2/13] END .........Lasso__alpha=0.005;, score=-0.572 total time=   0.7s
# [CV 3/5; 2/13] START Lasso__alpha=0.005.........................................
# [CV 3/5; 2/13] END .........Lasso__alpha=0.005;, score=-0.579 total time=   0.6s
# [CV 4/5; 2/13] START Lasso__alpha=0.005.........................................
# [CV 4/5; 2/13] END .........Lasso__alpha=0.005;, score=-0.577 total time=   0.6s
# [CV 5/5; 2/13] START Lasso__alpha=0.005.........................................
# [CV 5/5; 2/13] END .........Lasso__alpha=0.005;, score=-0.582 total time=   1.0s
# [CV 1/5; 3/13] START Lasso__alpha=0.01..........................................
# [CV 1/5; 3/13] END ..........Lasso__alpha=0.01;, score=-0.583 total time=   0.7s
# [CV 2/5; 3/13] START Lasso__alpha=0.01..........................................
# [CV 2/5; 3/13] END ..........Lasso__alpha=0.01;, score=-0.578 total time=   0.6s
# [CV 3/5; 3/13] START Lasso__alpha=0.01..........................................
# [CV 3/5; 3/13] END ..........Lasso__alpha=0.01;, score=-0.585 total time=   0.9s
# [CV 4/5; 3/13] START Lasso__alpha=0.01..........................................
# [CV 4/5; 3/13] END ..........Lasso__alpha=0.01;, score=-0.583 total time=   0.6s
# [CV 5/5; 3/13] START Lasso__alpha=0.01..........................................
# [CV 5/5; 3/13] END ..........Lasso__alpha=0.01;, score=-0.588 total time=   0.6s
# [CV 1/5; 4/13] START Lasso__alpha=0.025.........................................
# [CV 1/5; 4/13] END .........Lasso__alpha=0.025;, score=-0.588 total time=   0.4s
# [CV 2/5; 4/13] START Lasso__alpha=0.025.........................................
# [CV 2/5; 4/13] END .........Lasso__alpha=0.025;, score=-0.581 total time=   0.4s
# [CV 3/5; 4/13] START Lasso__alpha=0.025.........................................
# [CV 3/5; 4/13] END .........Lasso__alpha=0.025;, score=-0.590 total time=   0.4s
# [CV 4/5; 4/13] START Lasso__alpha=0.025.........................................
# [CV 4/5; 4/13] END .........Lasso__alpha=0.025;, score=-0.587 total time=   0.4s
# [CV 5/5; 4/13] START Lasso__alpha=0.025.........................................
# [CV 5/5; 4/13] END .........Lasso__alpha=0.025;, score=-0.593 total time=   0.4s
# [CV 1/5; 5/13] START Lasso__alpha=0.05..........................................
# [CV 1/5; 5/13] END ..........Lasso__alpha=0.05;, score=-0.598 total time=   0.3s
# [CV 2/5; 5/13] START Lasso__alpha=0.05..........................................
# [CV 2/5; 5/13] END ..........Lasso__alpha=0.05;, score=-0.590 total time=   0.6s
# [CV 3/5; 5/13] START Lasso__alpha=0.05..........................................
# [CV 3/5; 5/13] END ..........Lasso__alpha=0.05;, score=-0.601 total time=   0.7s
# [CV 4/5; 5/13] START Lasso__alpha=0.05..........................................
# [CV 4/5; 5/13] END ..........Lasso__alpha=0.05;, score=-0.597 total time=   0.4s
# [CV 5/5; 5/13] START Lasso__alpha=0.05..........................................
# [CV 5/5; 5/13] END ..........Lasso__alpha=0.05;, score=-0.603 total time=   0.3s
# [CV 1/5; 6/13] START Lasso__alpha=0.1...........................................
# [CV 1/5; 6/13] END ...........Lasso__alpha=0.1;, score=-0.606 total time=   0.3s
# [CV 2/5; 6/13] START Lasso__alpha=0.1...........................................
# [CV 2/5; 6/13] END ...........Lasso__alpha=0.1;, score=-0.598 total time=   0.4s
# [CV 3/5; 6/13] START Lasso__alpha=0.1...........................................
# [CV 3/5; 6/13] END ...........Lasso__alpha=0.1;, score=-0.609 total time=   0.3s
# [CV 4/5; 6/13] START Lasso__alpha=0.1...........................................
# [CV 4/5; 6/13] END ...........Lasso__alpha=0.1;, score=-0.607 total time=   0.3s
# [CV 5/5; 6/13] START Lasso__alpha=0.1...........................................
# [CV 5/5; 6/13] END ...........Lasso__alpha=0.1;, score=-0.614 total time=   0.3s
# [CV 1/5; 7/13] START Lasso__alpha=0.5...........................................
# [CV 1/5; 7/13] END ...........Lasso__alpha=0.5;, score=-0.775 total time=   0.3s
# [CV 2/5; 7/13] START Lasso__alpha=0.5...........................................
# [CV 2/5; 7/13] END ...........Lasso__alpha=0.5;, score=-0.774 total time=   0.3s
# [CV 3/5; 7/13] START Lasso__alpha=0.5...........................................
# [CV 3/5; 7/13] END ...........Lasso__alpha=0.5;, score=-0.775 total time=   0.2s
# [CV 4/5; 7/13] START Lasso__alpha=0.5...........................................
# [CV 4/5; 7/13] END ...........Lasso__alpha=0.5;, score=-0.794 total time=   0.3s
# [CV 5/5; 7/13] START Lasso__alpha=0.5...........................................
# [CV 5/5; 7/13] END ...........Lasso__alpha=0.5;, score=-0.791 total time=   0.4s
# [CV 1/5; 8/13] START Lasso__alpha=1.............................................
# [CV 1/5; 8/13] END .............Lasso__alpha=1;, score=-0.797 total time=   0.8s
# [CV 2/5; 8/13] START Lasso__alpha=1.............................................
# [CV 2/5; 8/13] END .............Lasso__alpha=1;, score=-0.795 total time=   0.7s
# [CV 3/5; 8/13] START Lasso__alpha=1.............................................
# [CV 3/5; 8/13] END .............Lasso__alpha=1;, score=-0.797 total time=   0.4s
# [CV 4/5; 8/13] START Lasso__alpha=1.............................................
# [CV 4/5; 8/13] END .............Lasso__alpha=1;, score=-0.813 total time=   0.4s
# [CV 5/5; 8/13] START Lasso__alpha=1.............................................
# [CV 5/5; 8/13] END .............Lasso__alpha=1;, score=-0.810 total time=   0.4s
# [CV 1/5; 9/13] START Lasso__alpha=5.............................................
# [CV 1/5; 9/13] END .............Lasso__alpha=5;, score=-0.797 total time=   0.4s
# [CV 2/5; 9/13] START Lasso__alpha=5.............................................
# [CV 2/5; 9/13] END .............Lasso__alpha=5;, score=-0.795 total time=   0.3s
# [CV 3/5; 9/13] START Lasso__alpha=5.............................................
# [CV 3/5; 9/13] END .............Lasso__alpha=5;, score=-0.797 total time=   0.3s
# [CV 4/5; 9/13] START Lasso__alpha=5.............................................
# [CV 4/5; 9/13] END .............Lasso__alpha=5;, score=-0.813 total time=   0.3s
# [CV 5/5; 9/13] START Lasso__alpha=5.............................................
# [CV 5/5; 9/13] END .............Lasso__alpha=5;, score=-0.810 total time=   0.3s
# [CV 1/5; 10/13] START Lasso__alpha=10...........................................
# [CV 1/5; 10/13] END ...........Lasso__alpha=10;, score=-0.797 total time=   0.3s
# [CV 2/5; 10/13] START Lasso__alpha=10...........................................
# [CV 2/5; 10/13] END ...........Lasso__alpha=10;, score=-0.795 total time=   0.3s
# [CV 3/5; 10/13] START Lasso__alpha=10...........................................
# [CV 3/5; 10/13] END ...........Lasso__alpha=10;, score=-0.797 total time=   0.3s
# [CV 4/5; 10/13] START Lasso__alpha=10...........................................
# [CV 4/5; 10/13] END ...........Lasso__alpha=10;, score=-0.813 total time=   0.3s
# [CV 5/5; 10/13] START Lasso__alpha=10...........................................
# [CV 5/5; 10/13] END ...........Lasso__alpha=10;, score=-0.810 total time=   0.3s
# [CV 1/5; 11/13] START Lasso__alpha=25...........................................
# [CV 1/5; 11/13] END ...........Lasso__alpha=25;, score=-0.797 total time=   0.3s
# [CV 2/5; 11/13] START Lasso__alpha=25...........................................
# [CV 2/5; 11/13] END ...........Lasso__alpha=25;, score=-0.795 total time=   0.3s
# [CV 3/5; 11/13] START Lasso__alpha=25...........................................
# [CV 3/5; 11/13] END ...........Lasso__alpha=25;, score=-0.797 total time=   0.3s
# [CV 4/5; 11/13] START Lasso__alpha=25...........................................
# [CV 4/5; 11/13] END ...........Lasso__alpha=25;, score=-0.813 total time=   0.3s
# [CV 5/5; 11/13] START Lasso__alpha=25...........................................
# [CV 5/5; 11/13] END ...........Lasso__alpha=25;, score=-0.810 total time=   0.3s
# [CV 1/5; 12/13] START Lasso__alpha=50...........................................
# [CV 1/5; 12/13] END ...........Lasso__alpha=50;, score=-0.797 total time=   0.4s
# [CV 2/5; 12/13] START Lasso__alpha=50...........................................
# [CV 2/5; 12/13] END ...........Lasso__alpha=50;, score=-0.795 total time=   0.5s
# [CV 3/5; 12/13] START Lasso__alpha=50...........................................
# [CV 3/5; 12/13] END ...........Lasso__alpha=50;, score=-0.797 total time=   0.4s
# [CV 4/5; 12/13] START Lasso__alpha=50...........................................
# [CV 4/5; 12/13] END ...........Lasso__alpha=50;, score=-0.813 total time=   0.3s
# [CV 5/5; 12/13] START Lasso__alpha=50...........................................
# [CV 5/5; 12/13] END ...........Lasso__alpha=50;, score=-0.810 total time=   0.4s
# [CV 1/5; 13/13] START Lasso__alpha=100..........................................
# [CV 1/5; 13/13] END ..........Lasso__alpha=100;, score=-0.797 total time=   0.4s
# [CV 2/5; 13/13] START Lasso__alpha=100..........................................
# [CV 2/5; 13/13] END ..........Lasso__alpha=100;, score=-0.795 total time=   0.4s
# [CV 3/5; 13/13] START Lasso__alpha=100..........................................
# [CV 3/5; 13/13] END ..........Lasso__alpha=100;, score=-0.797 total time=   0.3s
# [CV 4/5; 13/13] START Lasso__alpha=100..........................................
# [CV 4/5; 13/13] END ..........Lasso__alpha=100;, score=-0.813 total time=   0.3s
# [CV 5/5; 13/13] START Lasso__alpha=100..........................................
# [CV 5/5; 13/13] END ..........Lasso__alpha=100;, score=-0.810 total time=   0.3s
# {'Lasso__alpha': 0.001}
# RMSE = 0.5697383343865633

# %% [markdown]
# ### L2: Ridge
# ### Kaggle Private Score: 660,176
# ### In-sample RMSE: 0.5684734992787926, alpha = 5

# %%
# Define the pipeline for preprocessing and the classifier.
ridge_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('Ridge', Ridge())])

# Check structure of pipeline:
ridge_pipeline

param_grid = {
                'Ridge__alpha' : [0.001, 0.005, 0.01, 0.025, 0.05, 0.1, 0.5, 1, 5, 10, 25, 50, 100]}# 5 is chosen
grid_search_ridge = GridSearchCV(ridge_pipeline,
                           param_grid,
                           cv=5,
                           scoring = "neg_root_mean_squared_error",
                           verbose = 10)
# Fit the grid search
grid_search_ridge.fit(X_simple, y)

# Get best parameters
print(grid_search_ridge.best_params_)

# Get in sampple predictions and RMSE
y_hat_in_ridge = grid_search_ridge.predict(X_simple)

# Check in sample RMSE
print(f"RMSE = {root_mean_squared_error(y, y_hat_in_ridge)}")

y_hat_test_ridge = np.exp(grid_search_ridge.predict(test[X_simple.columns]))
test_predictions_submit = pd.DataFrame({"lotid": test["lotid"], "parcelvalue": y_hat_test_ridge})
test_predictions_submit.to_csv("test_predictions_ridge.csv", index = False)
# Out:
# Fitting 5 folds for each of 13 candidates, totalling 65 fits
# [CV 1/5; 1/13] START Ridge__alpha=0.001.........................................
# [CV 1/5; 1/13] END .........Ridge__alpha=0.001;, score=-0.569 total time=   0.7s
# [CV 2/5; 1/13] START Ridge__alpha=0.001.........................................
# [CV 2/5; 1/13] END .........Ridge__alpha=0.001;, score=-0.563 total time=   0.3s
# [CV 3/5; 1/13] START Ridge__alpha=0.001.........................................
# [CV 3/5; 1/13] END .........Ridge__alpha=0.001;, score=-0.573 total time=   0.3s
# [CV 4/5; 1/13] START Ridge__alpha=0.001.........................................
# [CV 4/5; 1/13] END .........Ridge__alpha=0.001;, score=-0.569 total time=   0.3s
# [CV 5/5; 1/13] START Ridge__alpha=0.001.........................................
# [CV 5/5; 1/13] END .........Ridge__alpha=0.001;, score=-0.574 total time=   0.3s
# [CV 1/5; 2/13] START Ridge__alpha=0.005.........................................
# [CV 1/5; 2/13] END .........Ridge__alpha=0.005;, score=-0.569 total time=   0.2s
# [CV 2/5; 2/13] START Ridge__alpha=0.005.........................................
# [CV 2/5; 2/13] END .........Ridge__alpha=0.005;, score=-0.563 total time=   0.2s
# [CV 3/5; 2/13] START Ridge__alpha=0.005.........................................
# [CV 3/5; 2/13] END .........Ridge__alpha=0.005;, score=-0.573 total time=   0.3s
# [CV 4/5; 2/13] START Ridge__alpha=0.005.........................................
# [CV 4/5; 2/13] END .........Ridge__alpha=0.005;, score=-0.569 total time=   0.2s
# [CV 5/5; 2/13] START Ridge__alpha=0.005.........................................
# [CV 5/5; 2/13] END .........Ridge__alpha=0.005;, score=-0.574 total time=   0.2s
# [CV 1/5; 3/13] START Ridge__alpha=0.01..........................................
# [CV 1/5; 3/13] END ..........Ridge__alpha=0.01;, score=-0.569 total time=   0.2s
# [CV 2/5; 3/13] START Ridge__alpha=0.01..........................................
# [CV 2/5; 3/13] END ..........Ridge__alpha=0.01;, score=-0.563 total time=   0.2s
# [CV 3/5; 3/13] START Ridge__alpha=0.01..........................................
# [CV 3/5; 3/13] END ..........Ridge__alpha=0.01;, score=-0.573 total time=   0.3s
# [CV 4/5; 3/13] START Ridge__alpha=0.01..........................................
# [CV 4/5; 3/13] END ..........Ridge__alpha=0.01;, score=-0.569 total time=   0.3s
# [CV 5/5; 3/13] START Ridge__alpha=0.01..........................................
# [CV 5/5; 3/13] END ..........Ridge__alpha=0.01;, score=-0.574 total time=   0.3s
# [CV 1/5; 4/13] START Ridge__alpha=0.025.........................................
# [CV 1/5; 4/13] END .........Ridge__alpha=0.025;, score=-0.569 total time=   0.2s
# [CV 2/5; 4/13] START Ridge__alpha=0.025.........................................
# [CV 2/5; 4/13] END .........Ridge__alpha=0.025;, score=-0.563 total time=   0.3s
# [CV 3/5; 4/13] START Ridge__alpha=0.025.........................................
# [CV 3/5; 4/13] END .........Ridge__alpha=0.025;, score=-0.573 total time=   0.3s
# [CV 4/5; 4/13] START Ridge__alpha=0.025.........................................
# [CV 4/5; 4/13] END .........Ridge__alpha=0.025;, score=-0.569 total time=   0.3s
# [CV 5/5; 4/13] START Ridge__alpha=0.025.........................................
# [CV 5/5; 4/13] END .........Ridge__alpha=0.025;, score=-0.574 total time=   0.3s
# [CV 1/5; 5/13] START Ridge__alpha=0.05..........................................
# [CV 1/5; 5/13] END ..........Ridge__alpha=0.05;, score=-0.569 total time=   0.3s
# [CV 2/5; 5/13] START Ridge__alpha=0.05..........................................
# [CV 2/5; 5/13] END ..........Ridge__alpha=0.05;, score=-0.563 total time=   0.3s
# [CV 3/5; 5/13] START Ridge__alpha=0.05..........................................
# [CV 3/5; 5/13] END ..........Ridge__alpha=0.05;, score=-0.573 total time=   0.3s
# [CV 4/5; 5/13] START Ridge__alpha=0.05..........................................
# [CV 4/5; 5/13] END ..........Ridge__alpha=0.05;, score=-0.569 total time=   0.3s
# [CV 5/5; 5/13] START Ridge__alpha=0.05..........................................
# [CV 5/5; 5/13] END ..........Ridge__alpha=0.05;, score=-0.574 total time=   0.3s
# [CV 1/5; 6/13] START Ridge__alpha=0.1...........................................
# [CV 1/5; 6/13] END ...........Ridge__alpha=0.1;, score=-0.569 total time=   0.3s
# [CV 2/5; 6/13] START Ridge__alpha=0.1...........................................
# [CV 2/5; 6/13] END ...........Ridge__alpha=0.1;, score=-0.563 total time=   0.3s
# [CV 3/5; 6/13] START Ridge__alpha=0.1...........................................
# [CV 3/5; 6/13] END ...........Ridge__alpha=0.1;, score=-0.573 total time=   0.2s
# [CV 4/5; 6/13] START Ridge__alpha=0.1...........................................
# [CV 4/5; 6/13] END ...........Ridge__alpha=0.1;, score=-0.569 total time=   0.3s
# [CV 5/5; 6/13] START Ridge__alpha=0.1...........................................
# [CV 5/5; 6/13] END ...........Ridge__alpha=0.1;, score=-0.574 total time=   0.2s
# [CV 1/5; 7/13] START Ridge__alpha=0.5...........................................
# [CV 1/5; 7/13] END ...........Ridge__alpha=0.5;, score=-0.569 total time=   0.2s
# [CV 2/5; 7/13] START Ridge__alpha=0.5...........................................
# [CV 2/5; 7/13] END ...........Ridge__alpha=0.5;, score=-0.563 total time=   0.2s
# [CV 3/5; 7/13] START Ridge__alpha=0.5...........................................
# [CV 3/5; 7/13] END ...........Ridge__alpha=0.5;, score=-0.573 total time=   0.2s
# [CV 4/5; 7/13] START Ridge__alpha=0.5...........................................
# [CV 4/5; 7/13] END ...........Ridge__alpha=0.5;, score=-0.569 total time=   0.2s
# [CV 5/5; 7/13] START Ridge__alpha=0.5...........................................
# [CV 5/5; 7/13] END ...........Ridge__alpha=0.5;, score=-0.574 total time=   0.2s
# [CV 1/5; 8/13] START Ridge__alpha=1.............................................
# [CV 1/5; 8/13] END .............Ridge__alpha=1;, score=-0.569 total time=   0.2s
# [CV 2/5; 8/13] START Ridge__alpha=1.............................................
# [CV 2/5; 8/13] END .............Ridge__alpha=1;, score=-0.563 total time=   0.2s
# [CV 3/5; 8/13] START Ridge__alpha=1.............................................
# [CV 3/5; 8/13] END .............Ridge__alpha=1;, score=-0.573 total time=   0.2s
# [CV 4/5; 8/13] START Ridge__alpha=1.............................................
# [CV 4/5; 8/13] END .............Ridge__alpha=1;, score=-0.569 total time=   0.2s
# [CV 5/5; 8/13] START Ridge__alpha=1.............................................
# [CV 5/5; 8/13] END .............Ridge__alpha=1;, score=-0.574 total time=   0.2s
# [CV 1/5; 9/13] START Ridge__alpha=5.............................................
# [CV 1/5; 9/13] END .............Ridge__alpha=5;, score=-0.569 total time=   0.2s
# [CV 2/5; 9/13] START Ridge__alpha=5.............................................
# [CV 2/5; 9/13] END .............Ridge__alpha=5;, score=-0.563 total time=   0.2s
# [CV 3/5; 9/13] START Ridge__alpha=5.............................................
# [CV 3/5; 9/13] END .............Ridge__alpha=5;, score=-0.572 total time=   0.2s
# [CV 4/5; 9/13] START Ridge__alpha=5.............................................
# [CV 4/5; 9/13] END .............Ridge__alpha=5;, score=-0.569 total time=   0.2s
# [CV 5/5; 9/13] START Ridge__alpha=5.............................................
# [CV 5/5; 9/13] END .............Ridge__alpha=5;, score=-0.574 total time=   0.2s
# [CV 1/5; 10/13] START Ridge__alpha=10...........................................
# [CV 1/5; 10/13] END ...........Ridge__alpha=10;, score=-0.569 total time=   0.2s
# [CV 2/5; 10/13] START Ridge__alpha=10...........................................
# [CV 2/5; 10/13] END ...........Ridge__alpha=10;, score=-0.563 total time=   0.2s
# [CV 3/5; 10/13] START Ridge__alpha=10...........................................
# [CV 3/5; 10/13] END ...........Ridge__alpha=10;, score=-0.572 total time=   0.2s
# [CV 4/5; 10/13] START Ridge__alpha=10...........................................
# [CV 4/5; 10/13] END ...........Ridge__alpha=10;, score=-0.569 total time=   0.2s
# [CV 5/5; 10/13] START Ridge__alpha=10...........................................
# [CV 5/5; 10/13] END ...........Ridge__alpha=10;, score=-0.574 total time=   0.2s
# [CV 1/5; 11/13] START Ridge__alpha=25...........................................
# [CV 1/5; 11/13] END ...........Ridge__alpha=25;, score=-0.569 total time=   0.2s
# [CV 2/5; 11/13] START Ridge__alpha=25...........................................
# [CV 2/5; 11/13] END ...........Ridge__alpha=25;, score=-0.563 total time=   0.2s
# [CV 3/5; 11/13] START Ridge__alpha=25...........................................
# [CV 3/5; 11/13] END ...........Ridge__alpha=25;, score=-0.572 total time=   0.2s
# [CV 4/5; 11/13] START Ridge__alpha=25...........................................
# [CV 4/5; 11/13] END ...........Ridge__alpha=25;, score=-0.569 total time=   0.2s
# [CV 5/5; 11/13] START Ridge__alpha=25...........................................
# [CV 5/5; 11/13] END ...........Ridge__alpha=25;, score=-0.574 total time=   0.2s
# [CV 1/5; 12/13] START Ridge__alpha=50...........................................
# [CV 1/5; 12/13] END ...........Ridge__alpha=50;, score=-0.569 total time=   0.2s
# [CV 2/5; 12/13] START Ridge__alpha=50...........................................
# [CV 2/5; 12/13] END ...........Ridge__alpha=50;, score=-0.564 total time=   0.2s
# [CV 3/5; 12/13] START Ridge__alpha=50...........................................
# [CV 3/5; 12/13] END ...........Ridge__alpha=50;, score=-0.572 total time=   0.2s
# [CV 4/5; 12/13] START Ridge__alpha=50...........................................
# [CV 4/5; 12/13] END ...........Ridge__alpha=50;, score=-0.569 total time=   0.2s
# [CV 5/5; 12/13] START Ridge__alpha=50...........................................
# [CV 5/5; 12/13] END ...........Ridge__alpha=50;, score=-0.575 total time=   0.2s
# [CV 1/5; 13/13] START Ridge__alpha=100..........................................
# [CV 1/5; 13/13] END ..........Ridge__alpha=100;, score=-0.570 total time=   0.2s
# [CV 2/5; 13/13] START Ridge__alpha=100..........................................
# [CV 2/5; 13/13] END ..........Ridge__alpha=100;, score=-0.564 total time=   0.2s
# [CV 3/5; 13/13] START Ridge__alpha=100..........................................
# [CV 3/5; 13/13] END ..........Ridge__alpha=100;, score=-0.573 total time=   0.2s
# [CV 4/5; 13/13] START Ridge__alpha=100..........................................
# [CV 4/5; 13/13] END ..........Ridge__alpha=100;, score=-0.570 total time=   0.3s
# [CV 5/5; 13/13] START Ridge__alpha=100..........................................
# [CV 5/5; 13/13] END ..........Ridge__alpha=100;, score=-0.575 total time=   0.2s
# {'Ridge__alpha': 5}
# RMSE = 0.5684734992787926

# %% [markdown]
# ### ElasticNet
# ### Kaggle Private Score: 661,815
# ### In-sample performance: 0.5689273730098059

# %%
from sklearn.linear_model import ElasticNet


elastic_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ElasticNet', ElasticNet(max_iter=10000))
])

param_grid = {
    'ElasticNet__alpha':    [0.001, 0.01, 0.1, 1, 10],    
    'ElasticNet__l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9] 
}

# Initiate grid search object
grid_search_elastic = GridSearchCV(elastic_pipeline,
                           param_grid,
                           cv=5,
                           scoring = "neg_root_mean_squared_error",
                           verbose = 10)
# Fit the grid search
grid_search_elastic.fit(X_simple, y)

# Get best parameters
print(grid_search_elastic.best_params_)

# Get in sampple predictions and RMSE
y_hat_in_ridge = grid_search_elastic.predict(X_simple)

# Check in sample RMSE
print(f"RMSE = {root_mean_squared_error(y, y_hat_in_ridge)}") # RMSE = 0.5164723492805274 (log values)

y_hat_test_ridge = np.exp(grid_search_elastic.predict(test[X_simple.columns]))
test_predictions_submit = pd.DataFrame({"lotid": test["lotid"], "parcelvalue": y_hat_test_ridge})
test_predictions_submit.to_csv("test_predictions_elastic.csv", index = False)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5; 1/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1..........
# [CV 1/5; 1/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1;, score=-0.569 total time=   5.6s
# [CV 2/5; 1/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1..........
# [CV 2/5; 1/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1;, score=-0.563 total time=   7.8s
# [CV 3/5; 1/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1..........
# [CV 3/5; 1/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1;, score=-0.572 total time=   4.6s
# [CV 4/5; 1/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1..........
# [CV 4/5; 1/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1;, score=-0.569 total time=   4.9s
# [CV 5/5; 1/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1..........
# [CV 5/5; 1/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.1;, score=-0.574 total time=   4.6s
# [CV 1/5; 2/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3..........
# [CV 1/5; 2/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3;, score=-0.569 total time=   1.5s
# [CV 2/5; 2/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3..........
# [CV 2/5; 2/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3;, score=-0.564 total time=   2.0s
# [CV 3/5; 2/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3..........
# [CV 3/5; 2/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3;, score=-0.572 total time=   2.0s
# [CV 4/5; 2/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3..........
# [CV 4/5; 2/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3;, score=-0.569 total time=   2.1s
# [CV 5/5; 2/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3..........
# [CV 5/5; 2/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.3;, score=-0.575 total time=   2.4s
# [CV 1/5; 3/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5..........
# [CV 1/5; 3/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5;, score=-0.569 total time=   0.8s
# [CV 2/5; 3/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5..........
# [CV 2/5; 3/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5;, score=-0.564 total time=   2.0s
# [CV 3/5; 3/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5..........
# [CV 3/5; 3/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5;, score=-0.573 total time=   0.6s
# [CV 4/5; 3/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5..........
# [CV 4/5; 3/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5;, score=-0.569 total time=   0.7s
# [CV 5/5; 3/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5..........
# [CV 5/5; 3/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.5;, score=-0.575 total time=   1.6s
# [CV 1/5; 4/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7..........
# [CV 1/5; 4/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7;, score=-0.570 total time=   0.6s
# [CV 2/5; 4/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7..........
# [CV 2/5; 4/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7;, score=-0.564 total time=   1.3s
# [CV 3/5; 4/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7..........
# [CV 3/5; 4/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7;, score=-0.573 total time=   0.6s
# [CV 4/5; 4/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7..........
# [CV 4/5; 4/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7;, score=-0.570 total time=   1.6s
# [CV 5/5; 4/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7..........
# [CV 5/5; 4/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.7;, score=-0.575 total time=   0.8s
# [CV 1/5; 5/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9..........
# [CV 1/5; 5/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9;, score=-0.570 total time=   0.9s
# [CV 2/5; 5/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9..........
# [CV 2/5; 5/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9;, score=-0.564 total time=   0.8s
# [CV 3/5; 5/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9..........
# [CV 3/5; 5/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9;, score=-0.573 total time=   0.8s
# [CV 4/5; 5/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9..........
# [CV 4/5; 5/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9;, score=-0.570 total time=   1.7s
# [CV 5/5; 5/25] START ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9..........
# [CV 5/5; 5/25] END ElasticNet__alpha=0.001, ElasticNet__l1_ratio=0.9;, score=-0.575 total time=   0.8s
# [CV 1/5; 6/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1...........
# [CV 1/5; 6/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1;, score=-0.571 total time=   0.7s
# [CV 2/5; 6/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1...........
# [CV 2/5; 6/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1;, score=-0.567 total time=   0.7s
# [CV 3/5; 6/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1...........
# [CV 3/5; 6/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1;, score=-0.575 total time=   0.7s
# [CV 4/5; 6/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1...........
# [CV 4/5; 6/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1;, score=-0.572 total time=   0.7s
# [CV 5/5; 6/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1...........
# [CV 5/5; 6/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.1;, score=-0.577 total time=   0.6s
# [CV 1/5; 7/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3...........
# [CV 1/5; 7/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3;, score=-0.575 total time=   0.5s
# [CV 2/5; 7/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3...........
# [CV 2/5; 7/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3;, score=-0.570 total time=   0.5s
# [CV 3/5; 7/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3...........
# [CV 3/5; 7/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3;, score=-0.577 total time=   0.5s
# [CV 4/5; 7/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3...........
# [CV 4/5; 7/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3;, score=-0.575 total time=   0.5s
# [CV 5/5; 7/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3...........
# [CV 5/5; 7/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.3;, score=-0.580 total time=   0.5s
# [CV 1/5; 8/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5...........
# [CV 1/5; 8/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5;, score=-0.577 total time=   0.6s
# [CV 2/5; 8/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5...........
# [CV 2/5; 8/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5;, score=-0.573 total time=   0.5s
# [CV 3/5; 8/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5...........
# [CV 3/5; 8/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5;, score=-0.580 total time=   0.5s
# [CV 4/5; 8/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5...........
# [CV 4/5; 8/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5;, score=-0.578 total time=   0.5s
# [CV 5/5; 8/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5...........
# [CV 5/5; 8/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.5;, score=-0.582 total time=   0.5s
# [CV 1/5; 9/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7...........
# [CV 1/5; 9/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7;, score=-0.580 total time=   0.5s
# [CV 2/5; 9/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7...........
# [CV 2/5; 9/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7;, score=-0.575 total time=   0.5s
# [CV 3/5; 9/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7...........
# [CV 3/5; 9/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7;, score=-0.582 total time=   0.5s
# [CV 4/5; 9/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7...........
# [CV 4/5; 9/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7;, score=-0.581 total time=   0.5s
# [CV 5/5; 9/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7...........
# [CV 5/5; 9/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.7;, score=-0.585 total time=   0.5s
# [CV 1/5; 10/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9..........
# [CV 1/5; 10/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9;, score=-0.583 total time=   0.5s
# [CV 2/5; 10/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9..........
# [CV 2/5; 10/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9;, score=-0.578 total time=   0.6s
# [CV 3/5; 10/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9..........
# [CV 3/5; 10/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9;, score=-0.585 total time=   0.6s
# [CV 4/5; 10/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9..........
# [CV 4/5; 10/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9;, score=-0.583 total time=   0.5s
# [CV 5/5; 10/25] START ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9..........
# [CV 5/5; 10/25] END ElasticNet__alpha=0.01, ElasticNet__l1_ratio=0.9;, score=-0.588 total time=   0.7s
# [CV 1/5; 11/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1...........
# [CV 1/5; 11/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1;, score=-0.586 total time=   0.4s
# [CV 2/5; 11/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1...........
# [CV 2/5; 11/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1;, score=-0.580 total time=   0.3s
# [CV 3/5; 11/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1...........
# [CV 3/5; 11/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1;, score=-0.588 total time=   0.3s
# [CV 4/5; 11/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1...........
# [CV 4/5; 11/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1;, score=-0.586 total time=   0.3s
# [CV 5/5; 11/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1...........
# [CV 5/5; 11/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.1;, score=-0.591 total time=   0.3s
# [CV 1/5; 12/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3...........
# [CV 1/5; 12/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3;, score=-0.593 total time=   0.3s
# [CV 2/5; 12/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3...........
# [CV 2/5; 12/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3;, score=-0.585 total time=   0.3s
# [CV 3/5; 12/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3...........
# [CV 3/5; 12/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3;, score=-0.595 total time=   0.3s
# [CV 4/5; 12/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3...........
# [CV 4/5; 12/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3;, score=-0.592 total time=   0.3s
# [CV 5/5; 12/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3...........
# [CV 5/5; 12/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.3;, score=-0.598 total time=   0.3s
# [CV 1/5; 13/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5...........
# [CV 1/5; 13/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5;, score=-0.600 total time=   0.3s
# [CV 2/5; 13/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5...........
# [CV 2/5; 13/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5;, score=-0.592 total time=   0.3s
# [CV 3/5; 13/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5...........
# [CV 3/5; 13/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5;, score=-0.602 total time=   0.3s
# [CV 4/5; 13/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5...........
# [CV 4/5; 13/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5;, score=-0.599 total time=   0.3s
# [CV 5/5; 13/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5...........
# [CV 5/5; 13/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.5;, score=-0.606 total time=   0.3s
# [CV 1/5; 14/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7...........
# [CV 1/5; 14/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7;, score=-0.603 total time=   0.3s
# [CV 2/5; 14/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7...........
# [CV 2/5; 14/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7;, score=-0.594 total time=   0.3s
# [CV 3/5; 14/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7...........
# [CV 3/5; 14/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7;, score=-0.605 total time=   0.3s
# [CV 4/5; 14/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7...........
# [CV 4/5; 14/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7;, score=-0.603 total time=   0.3s
# [CV 5/5; 14/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7...........
# [CV 5/5; 14/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.7;, score=-0.609 total time=   0.3s
# [CV 1/5; 15/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9...........
# [CV 1/5; 15/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9;, score=-0.606 total time=   0.3s
# [CV 2/5; 15/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9...........
# [CV 2/5; 15/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9;, score=-0.597 total time=   0.3s
# [CV 3/5; 15/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9...........
# [CV 3/5; 15/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9;, score=-0.608 total time=   0.3s
# [CV 4/5; 15/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9...........
# [CV 4/5; 15/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9;, score=-0.606 total time=   0.3s
# [CV 5/5; 15/25] START ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9...........
# [CV 5/5; 15/25] END ElasticNet__alpha=0.1, ElasticNet__l1_ratio=0.9;, score=-0.613 total time=   0.3s
# [CV 1/5; 16/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1.............
# [CV 1/5; 16/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1;, score=-0.621 total time=   0.3s
# [CV 2/5; 16/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1.............
# [CV 2/5; 16/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1;, score=-0.613 total time=   0.3s
# [CV 3/5; 16/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1.............
# [CV 3/5; 16/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1;, score=-0.623 total time=   0.3s
# [CV 4/5; 16/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1.............
# [CV 4/5; 16/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1;, score=-0.624 total time=   0.3s
# [CV 5/5; 16/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1.............
# [CV 5/5; 16/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.1;, score=-0.631 total time=   0.3s
# [CV 1/5; 17/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3.............
# [CV 1/5; 17/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3;, score=-0.684 total time=   0.3s
# [CV 2/5; 17/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3.............
# [CV 2/5; 17/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3;, score=-0.680 total time=   0.2s
# [CV 3/5; 17/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3.............
# [CV 3/5; 17/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3;, score=-0.687 total time=   0.3s
# [CV 4/5; 17/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3.............
# [CV 4/5; 17/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3;, score=-0.694 total time=   0.3s
# [CV 5/5; 17/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3.............
# [CV 5/5; 17/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.3;, score=-0.699 total time=   0.3s
# [CV 1/5; 18/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5.............
# [CV 1/5; 18/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5;, score=-0.780 total time=   0.3s
# [CV 2/5; 18/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5.............
# [CV 2/5; 18/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5;, score=-0.779 total time=   0.3s
# [CV 3/5; 18/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5.............
# [CV 3/5; 18/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5;, score=-0.780 total time=   0.3s
# [CV 4/5; 18/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5.............
# [CV 4/5; 18/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5;, score=-0.798 total time=   0.3s
# [CV 5/5; 18/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5.............
# [CV 5/5; 18/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.5;, score=-0.795 total time=   0.3s
# [CV 1/5; 19/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7.............
# [CV 1/5; 19/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7;, score=-0.797 total time=   0.3s
# [CV 2/5; 19/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7.............
# [CV 2/5; 19/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7;, score=-0.795 total time=   0.3s
# [CV 3/5; 19/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7.............
# [CV 3/5; 19/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7;, score=-0.797 total time=   0.2s
# [CV 4/5; 19/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7.............
# [CV 4/5; 19/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7;, score=-0.813 total time=   0.2s
# [CV 5/5; 19/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7.............
# [CV 5/5; 19/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.7;, score=-0.810 total time=   0.3s
# [CV 1/5; 20/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9.............
# [CV 1/5; 20/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9;, score=-0.797 total time=   0.3s
# [CV 2/5; 20/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9.............
# [CV 2/5; 20/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9;, score=-0.795 total time=   0.3s
# [CV 3/5; 20/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9.............
# [CV 3/5; 20/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9;, score=-0.797 total time=   0.3s
# [CV 4/5; 20/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9.............
# [CV 4/5; 20/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9;, score=-0.813 total time=   0.3s
# [CV 5/5; 20/25] START ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9.............
# [CV 5/5; 20/25] END ElasticNet__alpha=1, ElasticNet__l1_ratio=0.9;, score=-0.810 total time=   0.3s
# [CV 1/5; 21/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1............
# [CV 1/5; 21/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1;, score=-0.797 total time=   0.3s
# [CV 2/5; 21/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1............
# [CV 2/5; 21/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1;, score=-0.795 total time=   0.3s
# [CV 3/5; 21/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1............
# [CV 3/5; 21/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1;, score=-0.797 total time=   0.2s
# [CV 4/5; 21/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1............
# [CV 4/5; 21/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1;, score=-0.813 total time=   0.3s
# [CV 5/5; 21/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1............
# [CV 5/5; 21/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.1;, score=-0.810 total time=   0.2s
# [CV 1/5; 22/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3............
# [CV 1/5; 22/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3;, score=-0.797 total time=   0.2s
# [CV 2/5; 22/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3............
# [CV 2/5; 22/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3;, score=-0.795 total time=   0.2s
# [CV 3/5; 22/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3............
# [CV 3/5; 22/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3;, score=-0.797 total time=   0.2s
# [CV 4/5; 22/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3............
# [CV 4/5; 22/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3;, score=-0.813 total time=   0.2s
# [CV 5/5; 22/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3............
# [CV 5/5; 22/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.3;, score=-0.810 total time=   0.2s
# [CV 1/5; 23/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5............
# [CV 1/5; 23/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5;, score=-0.797 total time=   0.3s
# [CV 2/5; 23/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5............
# [CV 2/5; 23/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5;, score=-0.795 total time=   0.3s
# [CV 3/5; 23/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5............
# [CV 3/5; 23/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5;, score=-0.797 total time=   0.3s
# [CV 4/5; 23/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5............
# [CV 4/5; 23/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5;, score=-0.813 total time=   0.3s
# [CV 5/5; 23/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5............
# [CV 5/5; 23/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.5;, score=-0.810 total time=   0.3s
# [CV 1/5; 24/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7............
# [CV 1/5; 24/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7;, score=-0.797 total time=   0.2s
# [CV 2/5; 24/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7............
# [CV 2/5; 24/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7;, score=-0.795 total time=   0.3s
# [CV 3/5; 24/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7............
# [CV 3/5; 24/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7;, score=-0.797 total time=   0.3s
# [CV 4/5; 24/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7............
# [CV 4/5; 24/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7;, score=-0.813 total time=   0.3s
# [CV 5/5; 24/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7............
# [CV 5/5; 24/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.7;, score=-0.810 total time=   0.3s
# [CV 1/5; 25/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9............
# [CV 1/5; 25/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9;, score=-0.797 total time=   0.3s
# [CV 2/5; 25/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9............
# [CV 2/5; 25/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9;, score=-0.795 total time=   0.3s
# [CV 3/5; 25/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9............
# [CV 3/5; 25/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9;, score=-0.797 total time=   0.3s
# [CV 4/5; 25/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9............
# [CV 4/5; 25/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9;, score=-0.813 total time=   0.3s
# [CV 5/5; 25/25] START ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9............
# [CV 5/5; 25/25] END ElasticNet__alpha=10, ElasticNet__l1_ratio=0.9;, score=-0.810 total time=   0.3s
# {'ElasticNet__alpha': 0.001, 'ElasticNet__l1_ratio': 0.1}
# RMSE = 0.5689273730098059

# %% [markdown]
# # 4 Feature Engineering
# - I did not use some of the features before.
# - Some features do not make sense, fx the numbedrooms = 0. I'll recode them.
# - Latitude and longitude were not used - see if we can derive some useful information from them.
# - Inpsect the city and region code variables.

# %% [markdown]
# ## Latitude and Longitude
# - See if there are clustering methods to derive some useful features
# - There seems to be a few hotspots of high value houses but no clear visual trend.

# %%
# Latitude and longitude are multiplied by $10^6$ in the datasets
for df in [train, test]:
    df['longitude'] = df['longitude']/10**6
    df['latitude'] = df['latitude']/10**6

# Load the county map. County map downloaded from https://gis.data.ca.gov/datasets/8713ced9b78a4abb97dc130a691a8695_0/explore?filters=eyJDT1VOVFlfTkFNRSI6WyJMb3MgQW5nZWxlcyJdfQ%3D%3D&location=34.524112%2C-117.443958%2C6.94
cali_map = gpd.read_file("../data/California_County_Boundaries/cnty19_1.shp")

# Get subset
geo_data = train[['log_parcelvalue', 'latitude', 'longitude']]

# Declare CRS
crs = {'init': 'epsg:4326'}

# Create geometry points using lat and long
geometry = [Point(xy) for xy in zip(geo_data['longitude'], geo_data['latitude'])]

# Make a geographic dataframe
geo_df = gpd.GeoDataFrame(geo_data,
                          crs = crs,
                          geometry = geometry)

# Plot the houses on the county map
fig, ax = plt.subplots(figsize = (8, 8))
cali_map.to_crs(epsg=4326).plot(ax = ax, color = 'lightgrey')
geo_df.plot(ax = ax, alpha = 0.1, column = 'log_parcelvalue', legend = True, cmap = 'inferno')
ax.set_title('Los Angeles, Ventura & Orange Counties: Real Estate')
# Out:
# /Users/gnlm/Desktop/ds_projects/housing/Housing-Prices-Prediction/.venv/lib/python3.9/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# Text(0.5, 1.0, 'Los Angeles, Ventura & Orange Counties: Real Estate')

# %% [markdown]
# ## Create grids around the points, similar to GIS.
# - We can use this feature to one-hot encode.
# - Visually, these grids make more sense than using K-means

# %%
# Try different values for grid sizes - 50 looks to capture enough observations
for df in [train,test]:
    df['lat_bin'] = (df['latitude'] * 50).round().astype(int)
    df['lon_bin'] = (df['longitude'] * 50).round().astype(int)
    df['geo_bin'] = df['lat_bin'].astype(str) + '_' + df['lon_bin'].astype(str)

lat_lon_bins = train.groupby(['lat_bin', 'lon_bin']).agg(mean_log_parcel_value = ('log_parcelvalue', 'mean')).reset_index()
lat_lon_bins = lat_lon_bins.pivot(index = 'lat_bin',
                                  columns = 'lon_bin',
                                  values = 'mean_log_parcel_value')

# Visualise bins:
plt.figure(figsize=(10, 8))
sns.heatmap(lat_lon_bins,
             cmap='viridis',
               cbar_kws={'label': 'Mean target'})

plt.title('Average Target Value by Latitude/Longitude Bin')
plt.xlabel('Longitude bin')
plt.ylabel('Latitude bin')
plt.show()

# %% [markdown]
# Target encode our grids using KFold to avoid data leakage
# - In addition, I use a smoothing factor k = 20 to blend each category’s mean with the global mean.

# %%
def oof_target_encode(train, test, col, target, n_splits=5, k=20):
    train_encoded = np.zeros(len(train))
    global_mean = train[target].mean()
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    for tr_idx, val_idx in kf.split(train):
        tr, val = train.iloc[tr_idx], train.iloc[val_idx]
        stats = tr.groupby(col)[target].agg(['mean', 'count'])
        smooth = (stats['count'] * stats['mean'] + k * global_mean) / (stats['count'] + k)
        train_encoded[val_idx] = val[col].map(smooth).fillna(global_mean)
    
    test_stats = train.groupby(col)[target].agg(['mean', 'count'])
    smooth = (test_stats['count'] * test_stats['mean'] + k * global_mean) / (test_stats['count'] + k)
    test_encoded = test[col].map(smooth).fillna(global_mean)
    
    return train_encoded, test_encoded

train['geo_bin_te'], test['geo_bin_te'] = oof_target_encode(train, test, 'geo_bin', 'log_parcelvalue')

# %% [markdown]
# ## Creating New Features
# I create the following features. These are mere subjective assessments of "relevant" features.
#
# - $Average\ room\ size = (Total\ finished\ area)/(Bedrooms)$
# - $Bed-Bathroom-Ratio = (Bathrooms)/(Bedrooms )$
# - Roomnums - doesnt make sense that there are so many zeros -> Most likely missing coded as NaN
# - Same thing for lotarea

# %%
for df in [train,test]:
    df['roomnum'] = df['roomnum'].replace(0, np.nan)
    df['lotarea'] = df['lotarea'].replace(0, np.nan)
    df['avg_room_size'] = df['finishedarea']/df['roomnum']
    df['bed_bath_ratio'] = (df['num34bath'] + df['numfullbath'])/df['roomnum']


train['roomnum'] = train['roomnum'].fillna(train['roomnum'].median())
test['roomnum'] = test['roomnum'].fillna(train['roomnum'].median())

train['lotarea_log'] = np.log1p(train['lotarea'])
train['lotarea_log'] = train['lotarea_log'].fillna(0)

test['lotarea_log'] = np.log1p(test['lotarea'])
test['lotarea_log'] = test['lotarea_log'].fillna(0)

# %% [markdown]
# ## 5.2 Dealing With High Cardinality Features: neighborhoodcode, regioncode, citycode
# For high cardinality features, it does not make sense to use them directly. Maybe the character of neighborhoodcode and citycode denote the general area of the house. I test my hypothesis here:
# - There seems to be no apparent relationship between the codes and the target feature.
# - Upon further online investigation, neighbourhoodcode and citycode are not even actual city codes that correspond to location.
# - Absence of other information, I drop these features.
# - regioncode roughly corresponds to the zipcode - can be onehotencoded.

# %%
# Check if first digits represent any useful information - Check upto 1, 2 and 3 chars
for df in [train, test]:
    df['citycode_small'] = df['citycode'].apply(lambda x: str(x)[:1] if not np.isnan(x) else x ) #:1,2,3
    df['neighborhoodcode_small'] = df['neighborhoodcode'].apply(lambda x: str(x)[:1] if not np.isnan(x) else x )

# Boxplots for new features
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Boxplots')
## Original
sns.boxplot(ax=axes[0], x = train.citycode_small, y = train.log_parcelvalue)
axes[0].set_title('Citycode')
## Log transformed
sns.boxplot(ax=axes[1], x = train.neighborhoodcode_small, y = train.log_parcelvalue)
axes[1].set_title('Neighborhoodcode')
# Out:
# Text(0.5, 1.0, 'Neighborhoodcode')

# %% [markdown]
# # Final Model

# %%
categorical= ['aircond', 'qualitybuild', 'decktype', 'tubflag', 'heatingtype',
               'taxdelinquencyflag', 'unitnum', 'regioncode']

numerical =   ['basement', 'numbedroom', 'finishedarea',
               'finishedareaEntry', 'numfireplace', 'numfullbath', 'garagenum', 
               'garagearea', 'lotarea_log', 'poolnum', 'poolarea', 'roomnum', 
               'num34bath', 'year', 'numstories', 'taxyear',
               'taxdelinquencyyear', 'avg_room_size', 'bed_bath_ratio', 'geo_bin_te']

final_features = categorical + numerical

X = train[final_features]
y = train[['log_parcelvalue']]

# %%
log_tranformer = FunctionTransformer(log_transform,
                                      feature_names_out = "one-to-one")

poly_features = ['finishedarea', 'finishedareaEntry' ]

numeric_transformer = Pipeline(
             steps = [
                      ("imputer", SimpleImputer(strategy = 'median')),
                      ("log", log_tranformer),
                      ("scaler", StandardScaler())
                      ])

poly_transformer = Pipeline(
             steps = [
                      ("imputer", SimpleImputer(strategy = 'median')),
                      ("log", log_tranformer),
                      ("poly", PolynomialFeatures(degree = 3, include_bias=False)),
                      ("scaler", StandardScaler())
                      ])

categorical_transformer = Pipeline(
             steps = [ ("imputer", SimpleImputer(strategy = "most_frequent")),
                        ( "ohe", OneHotEncoder(
                                                handle_unknown='ignore',
                                                sparse_output=False))])

# preprocessor pipeline combining both:
preprocessor = ColumnTransformer(transformers=[
        ("num", numeric_transformer, numerical),
        ("poly", poly_transformer, poly_features),
        ("cat", categorical_transformer, categorical),
        ])

# Define the pipeline for preprocessing and the classifier.
regression_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('regression', LinearRegression())])

# Check structure of pipeline:
regression_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('log',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<function log_transform at 0x103ab5d30>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['basement', 'numbedroom',
#                                                    'finishedarea',
#                                                    'finishedareaEntry',
#                                                    'numfireplace',
#                                                    'numfullbat...
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['finishedarea',
#                                                    'finishedareaEntry']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['aircond', 'qualitybuild',
#                                                    'decktype', 'tubflag',
#                                                    'heatingtype',
#                                                    'taxdelinquencyflag',
#                                                    'unitnum',
#                                                    'regioncode'])])),
#                 ('regression', LinearRegression())])

# %% [markdown]
# ## Simple Regression
# ## Kaggle Private Score 580,991
# ## In-sample performance: RMSE = 0.5378175037007888

# %%
models_and_grids = {
    "Lasso": (
        Lasso(max_iter=10000),
        {"model__alpha": [0.001, 0.005, 0.01, 0.025, 0.05, 0.1, 0.5, 1, 5, 10, 25, 50, 100]}),

    "Ridge": (
        Ridge(),
        {"model__alpha": [0.01, 0.1, 1, 10, 100]}),

    "ElasticNet": (
        ElasticNet(max_iter=10000),
        {
            "model__alpha":     [0.001, 0.01, 0.1, 1, 10],
            "model__l1_ratio":  [0.1, 0.3, 0.5, 0.7, 0.9]
        })}

# %%
results = []

for name, (estimator, grid) in models_and_grids.items():

    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('model', estimator)
    ])

    gs = GridSearchCV(
        pipe,
        grid,
        cv=5,
        scoring="neg_root_mean_squared_error",
        n_jobs=-1
    )

    gs.fit(X, y)

    best_rmse = -gs.best_score_
    best_params = gs.best_params_

    results.append({
        "model": name,
        "best_params": best_params,
        "rmse": best_rmse
    })
pd.DataFrame(results)
# Out:
#         model                                      best_params      rmse
# 0       Lasso                          {'model__alpha': 0.001}  0.550426
# 1       Ridge                              {'model__alpha': 1}  0.535697
# 2  ElasticNet  {'model__alpha': 0.001, 'model__l1_ratio': 0.1}  0.539671

# %% [markdown]
# ### Final Model
# ### Kaggle Private Score: 576,046
# ### In-sample performance: 0.5356970293492677

# %%
ridge_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('Ridge', Ridge(alpha=1))])
ridge_pipeline.fit(X,y)
y_hat_test_ridge = np.exp(ridge_pipeline.predict(test[X.columns]))
test_predictions_submit = pd.DataFrame({"lotid": test["lotid"], "parcelvalue": y_hat_test_ridge})
test_predictions_submit.to_csv("test_predictions_final.csv", index = False)

# %% [markdown]
# # Feature Importance: Location! Location!! Location!!!
#
# - Location Dominates Housing Prices
# - The model’s (Linear Regression) top coefficients (by absolute value) are almost entirely geographical features:
# - - One-hot-encoded region codes
#
# #### Interpretation:
# - This aligns with the real-estate principle: “Location is the strongest determinant of property value.”
# - Even after controlling for home characteristics (size, rooms, garage, features…),where the property is located explains the majority of price variation.
# - This is also visible in the feature importance ranking, where all the top 15 features are location-related.

# %%
ridge_pipeline.fit(X, y)
coefs = ridge_pipeline.named_steps["Ridge"].coef_
feature_names = ridge_pipeline.named_steps["preprocessor"].get_feature_names_out()

# DataFrame
coef_df = pd.DataFrame({
    "feature": feature_names,
    "coefficient": coefs
})

# Sort by importance (abs)
coef_df["abs_coef"] = coef_df["coefficient"].abs()
coef_df = coef_df.sort_values("abs_coef", ascending=False)

# Plot
plt.figure(figsize=(8, 12))
sns.barplot(
    data=coef_df.head(15),
    x="coefficient",
    y="feature",
    palette="viridis"
)
plt.title("Top 30 Ridge Feature Importances")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/z1/06t5y7z11fz24b5p636_mqnr0000gn/T/ipykernel_5350/134200448.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Tree-based Models:
# - For a quick check, I try fitting a basic XGBoost regression model to check if it performs better than linear models.
# - In-sample error = 0.4579288065433502, much lower than the linear models.
# - However, Kaggle private score = 608,301
# - Even without hyperparameter tuning, XGBoost outperformed the baseline linear regression model on both the training and test sets.
# - This shows that the dataset contains nonlinear patterns that a boosted-tree model can naturally exploit.
# - XGBoost was not tuned, so its performance represents only a “quick baseline” rather than a fully optimized model.

# %%
import xgboost as xgb

log_tranformer = FunctionTransformer(log_transform,
                                      feature_names_out = "one-to-one")

poly_features = ['finishedarea', 'finishedareaEntry' ]

numeric_transformer = Pipeline(
             steps = [
                      ("imputer", SimpleImputer(strategy = 'median')),
                      ("log", log_tranformer),
                      ("scaler", StandardScaler())
                      ])

poly_transformer = Pipeline(
             steps = [
                      ("imputer", SimpleImputer(strategy = 'median')),
                      ("log", log_tranformer),
                      ("poly", PolynomialFeatures(degree = 3, include_bias=False)),
                      ("scaler", StandardScaler())
                      ])

categorical_transformer = Pipeline(
             steps = [ ("imputer", SimpleImputer(strategy = "most_frequent")),
                        ( "ohe", OneHotEncoder(
                                                handle_unknown='ignore',
                                                sparse_output=False))])

# preprocessor pipeline combining both:
preprocessor = ColumnTransformer(transformers=[
        ("num", numeric_transformer, numerical),
        ("poly", poly_transformer, poly_features),
        ("cat", categorical_transformer, categorical),
        ])

# Define the pipeline for preprocessing and the classifier.
xgb_regression_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('regression', xgb.XGBRegressor(objective='reg:squarederror',
                         n_estimators=100, random_state=42))])

# Check structure of pipeline:
xgb_regression_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('log',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<function log_transform at 0x12d895820>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['basement', 'numbedroom',
#                                                    'finishedarea',
#                                                    'finishedareaEntry',
#                                                    'numfireplace',
#                                                    'numfullbat...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
xgb_regression_pipeline.fit(X, y)
# Get in sampple predictions and RMSE
y_hat_in_xgb = xgb_regression_pipeline.predict(X)

# Check in sample RMSE
print(f"RMSE = {root_mean_squared_error(y, y_hat_in_xgb)}") # RMSE = 0.5164723492805274 (log values)

y_hat_test_xgb = np.exp(xgb_regression_pipeline.predict(test[X.columns]))
test_predictions_submit = pd.DataFrame({"lotid": test["lotid"], "parcelvalue": y_hat_test_xgb})
test_predictions_submit.to_csv("test_predictions_xgb.csv", index = False)
# Out:
# RMSE = 0.4579288065433502
